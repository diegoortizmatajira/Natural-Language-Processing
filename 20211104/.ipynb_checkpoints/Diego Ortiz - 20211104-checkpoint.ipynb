# %% [markdown]
# # Illustrate Text Classification

# %%
# Libraries
import nltk

# %%
# Get Data from NLTK Corpus
nltk. download ('movie_reviews')
# Out:
# [nltk_data] Downloading package movie_reviews to
# [nltk_data]     C:\Users\diegoortizmatajira\AppData\Roaming\nltk_data.
# [nltk_data]     ..
# [nltk_data]   Package movie_reviews is already up-to-date!
# True

# %%
from nltk.corpus import movie_reviews

# %% [markdown]
# # Dataset

# %%
movie_reviews.words()
# Out:
# ['plot', ':', 'two', 'teen', 'couples', 'go', 'to', ...]

# %%
len(movie_reviews.words())
# Out:
# 1583820

# %%
movie_reviews.fileids()[:5]
# Out:
# ['neg/cv000_29416.txt',
#  'neg/cv001_19502.txt',
#  'neg/cv002_17424.txt',
#  'neg/cv003_12683.txt',
#  'neg/cv004_12641.txt']

# %%
movie_reviews.fileids()[-6:-1]
# Out:
# ['pos/cv994_12270.txt',
#  'pos/cv995_21821.txt',
#  'pos/cv996_11592.txt',
#  'pos/cv997_5046.txt',
#  'pos/cv998_14111.txt']

# %% [markdown]
# # Text Preprocessing

# %%
reviews = ' '.join(movie_reviews.words())
reviews[:300]
# Out:
# 'plot : two teen couples go to a church party , drink and then drive . they get into an accident . one of the guys dies , but his girlfriend continues to see him in her life , and has nightmares . what \' s the deal ? watch the movie and " sorta " find out . . . critique : a mind - fuck movie for the '

# %% [markdown]
# ## remove punctuation

# %%
import string

# %%
filtered_reviews = reviews.translate(str.maketrans('', '', string.punctuation))
filtered_reviews[:300]
# Out:
# 'plot  two teen couples go to a church party  drink and then drive  they get into an accident  one of the guys dies  but his girlfriend continues to see him in her life  and has nightmares  what  s the deal  watch the movie and  sorta  find out    critique  a mind  fuck movie for the teen generation '

# %% [markdown]
# ## Make lower and Tokenize

# %%
from nltk.tokenize import word_tokenize

# %%
tokens = word_tokenize(filtered_reviews.lower())
tokens[:10]
# Out:
# ['plot', 'two', 'teen', 'couples', 'go', 'to', 'a', 'church', 'party', 'drink']

# %% [markdown]
# ## Stopwords removal

# %%
from nltk.corpus import stopwords

# %%
stopwords_eng = stopwords.words('English')
filtered_tokens = [word for word in tokens if word not in stopwords_eng]
filtered_tokens [:30]
# Out:
# ['plot',
#  'two',
#  'teen',
#  'couples',
#  'go',
#  'church',
#  'party',
#  'drink',
#  'drive',
#  'get',
#  'accident',
#  'one',
#  'guys',
#  'dies',
#  'girlfriend',
#  'continues',
#  'see',
#  'life',
#  'nightmares',
#  'deal',
#  'watch',
#  'movie',
#  'sorta',
#  'find',
#  'critique',
#  'mind',
#  'fuck',
#  'movie',
#  'teen',
#  'generation']

# %% [markdown]
# ## Frequency of words

# %%
counter_dict = nltk.FreqDist(filtered_tokens)
counter_dict.most_common(10)
# Out:
# [('film', 9519),
#  ('one', 5853),
#  ('movie', 5774),
#  ('like', 3690),
#  ('even', 2565),
#  ('good', 2411),
#  ('time', 2411),
#  ('story', 2170),
#  ('would', 2110),
#  ('much', 2050)]

# %% [markdown]
# ## Create document with Categories

# %%
docs = [(list (movie_reviews.words(fileid)), category)
for category in movie_reviews.categories()
for fileid in movie_reviews.fileids(category)]

# %%
docs[1989:1990]
# Out:
# [(['lisa',
#    'cholodenko',
#    "'",
#    's',
#    '"',
#    'high',
#    'art',
#    ',',
#    '"',
#    'is',
#    'an',
#    'intelligent',
#    ',',
#    'quiet',
#    'drama',
#    '.',
#    'its',
#    'strongest',
#    'quality',
#    ',',
#    'aside',
#    'from',
#    'the',
#    'top',
#    '-',
#    'notch',
#    'central',
#    'performances',
#    ',',
#    'is',
#    'the',
#    'perceptive',
#    'way',
#    'in',
#    'which',
#    'the',
#    'film',
#    ',',
#    'also',
#    'written',
#    'by',
#    'cholodenko',
#    ',',
#    'observes',
#    'its',
#    'characters',
#    '.',
#    'they',
#    'are',
#    'all',
#    'flawed',
#    'people',
#    ',',
#    'some',
#    'more',
#    'troubled',
#    'than',
#    'others',
#    ',',
#    'but',
#    'they',
#    'are',
#    'not',
#    'judged',
#    '.',
#    'judging',
#    'the',
#    'characters',
#    'in',
#    'this',
#    'picture',
#    'would',
#    'be',
#    'a',
#    'creative',
#    'misstep',
#    'on',
#    'the',
#    'filmmakers',
#    "'",
#    'parts',
#    ',',
#    'because',
#    'no',
#    'one',
#    ',',
#    'no',
#    'matter',
#    'how',
#    'bad',
#    'off',
#    'they',
#    'are',
#    ',',
#    'deserve',
#    'to',
#    'be',
#    'negatively',
#    'judged',
#    'if',
#    'they',
#    'are',
#    'involved',
#    'in',
#    'some',
#    'serious',
#    'problems',
#    'that',
#    'they',
#    'cannot',
#    'break',
#    'free',
#    'of',
#    '.',
#    'syd',
#    '(',
#    'radha',
#    'mitchell',
#    ')',
#    ',',
#    'a',
#    '24',
#    '-',
#    'year',
#    '-',
#    'old',
#    'woman',
#    'living',
#    'with',
#    'her',
#    'longtime',
#    'boyfriend',
#    'james',
#    '(',
#    'gabriel',
#    'mann',
#    ')',
#    ',',
#    'has',
#    'recently',
#    'been',
#    'awarded',
#    'an',
#    'ideal',
#    'job',
#    'at',
#    'the',
#    'high',
#    '-',
#    'profile',
#    'photography',
#    'magazine',
#    ',',
#    '"',
#    'frame',
#    '.',
#    '"',
#    'she',
#    'very',
#    'much',
#    'enjoys',
#    'where',
#    'her',
#    'career',
#    'is',
#    'headed',
#    ',',
#    'but',
#    'is',
#    'often',
#    'not',
#    'taken',
#    'very',
#    'seriously',
#    'by',
#    'her',
#    'managers',
#    ',',
#    'who',
#    'are',
#    'always',
#    'giving',
#    'her',
#    'petty',
#    'jobs',
#    'to',
#    'do',
#    ',',
#    'when',
#    'she',
#    'knows',
#    'she',
#    'could',
#    'be',
#    'doing',
#    'more',
#    'important',
#    'things',
#    '.',
#    'one',
#    'night',
#    ',',
#    'while',
#    'taking',
#    'a',
#    'bath',
#    ',',
#    'syd',
#    'notices',
#    'a',
#    'leak',
#    'coming',
#    'from',
#    'the',
#    'apartment',
#    'above',
#    'hers',
#    ',',
#    'so',
#    'when',
#    'she',
#    'goes',
#    'up',
#    'there',
#    'to',
#    'inform',
#    'them',
#    'of',
#    'it',
#    ',',
#    'she',
#    'meets',
#    'lucy',
#    'beliner',
#    '(',
#    'ally',
#    'sheedy',
#    ')',
#    ',',
#    'a',
#    'thin',
#    ',',
#    'worn',
#    '-',
#    'out',
#    ',',
#    'and',
#    'unhappy',
#    'woman',
#    ',',
#    'who',
#    'lives',
#    'with',
#    'her',
#    'drug',
#    '-',
#    'addicted',
#    'german',
#    'girlfriend',
#    ',',
#    'greta',
#    '(',
#    'patricia',
#    'clarkson',
#    ')',
#    ',',
#    'a',
#    'pathetic',
#    'former',
#    'actress',
#    'who',
#    'is',
#    'usually',
#    'so',
#    'out',
#    '-',
#    'of',
#    '-',
#    'it',
#    'that',
#    'she',
#    'often',
#    'is',
#    'in',
#    'and',
#    'out',
#    'of',
#    'conciousness',
#    '.',
#    'syd',
#    'quickly',
#    'strikes',
#    'up',
#    'a',
#    'conversation',
#    'with',
#    'lucy',
#    ',',
#    'and',
#    'discovers',
#    'that',
#    'she',
#    'used',
#    'to',
#    'be',
#    'an',
#    'acclaimed',
#    'photographer',
#    'ten',
#    'years',
#    'before',
#    '.',
#    'lucy',
#    'claims',
#    'she',
#    'doesn',
#    "'",
#    't',
#    'want',
#    'to',
#    'get',
#    'back',
#    'into',
#    'the',
#    'profession',
#    ',',
#    'but',
#    'syd',
#    'manages',
#    'to',
#    'convince',
#    'the',
#    '"',
#    'frame',
#    '"',
#    'editors',
#    'to',
#    'do',
#    'a',
#    'piece',
#    'on',
#    'her',
#    'work',
#    '.',
#    'all',
#    'the',
#    'while',
#    ',',
#    'syd',
#    'begins',
#    'to',
#    'grow',
#    'deep',
#    'feelings',
#    'for',
#    'lucy',
#    ',',
#    'even',
#    'though',
#    'she',
#    'has',
#    'never',
#    'previously',
#    'been',
#    'attracted',
#    'to',
#    'a',
#    'woman',
#    ',',
#    'and',
#    'lucy',
#    'starts',
#    'a',
#    'battle',
#    'with',
#    'her',
#    'personal',
#    'demons',
#    '.',
#    '"',
#    'high',
#    'art',
#    ',',
#    '"',
#    'is',
#    'such',
#    'an',
#    'effective',
#    'motion',
#    'picture',
#    'because',
#    'it',
#    'is',
#    'never',
#    'suger',
#    '-',
#    'coated',
#    'or',
#    'idealized',
#    ',',
#    'but',
#    'instead',
#    'an',
#    'honest',
#    'and',
#    'convincing',
#    'portrait',
#    'of',
#    'a',
#    'handful',
#    'of',
#    'unhappy',
#    'people',
#    'whose',
#    'lives',
#    'are',
#    'going',
#    'nowhere',
#    ',',
#    'while',
#    'syd',
#    "'",
#    's',
#    'luck',
#    'begins',
#    'to',
#    'rise',
#    '.',
#    'the',
#    'film',
#    'in',
#    'no',
#    'way',
#    'is',
#    'about',
#    'lesbianism',
#    ',',
#    'but',
#    'about',
#    'love',
#    ',',
#    'which',
#    'was',
#    'a',
#    'refreshing',
#    'change',
#    'of',
#    'pace',
#    'from',
#    'the',
#    'usual',
#    'stereotypical',
#    'portraits',
#    'of',
#    'homosexuality',
#    '.',
#    'as',
#    'lucy',
#    'and',
#    'syd',
#    'grow',
#    'closer',
#    'and',
#    'closer',
#    'together',
#    ',',
#    'we',
#    'really',
#    'do',
#    'believe',
#    'that',
#    'they',
#    'are',
#    'falling',
#    'in',
#    'love',
#    'with',
#    'each',
#    'other',
#    ',',
#    'even',
#    'if',
#    'the',
#    'relationship',
#    'might',
#    'be',
#    'doomed',
#    '.',
#    'with',
#    'this',
#    'picture',
#    ',',
#    'ally',
#    'sheedy',
#    "'",
#    's',
#    'star',
#    'has',
#    'risen',
#    'once',
#    'again',
#    ',',
#    'thanks',
#    'to',
#    'her',
#    'touching',
#    ',',
#    'nearly',
#    'flawless',
#    'portrtayal',
#    'of',
#    'lucy',
#    ',',
#    'a',
#    'woman',
#    'who',
#    ',',
#    'in',
#    'the',
#    'course',
#    'of',
#    'a',
#    'decade',
#    ',',
#    'has',
#    'found',
#    'her',
#    'life',
#    'consumed',
#    'almost',
#    'entirely',
#    'by',
#    'drugs',
#    ',',
#    'which',
#    'has',
#    'taken',
#    'away',
#    'her',
#    'once',
#    '-',
#    'blossoming',
#    'career',
#    '.',
#    'her',
#    'characted',
#    'really',
#    'is',
#    'tragic',
#    ',',
#    'and',
#    'one',
#    'particular',
#    'scene',
#    'involving',
#    'lucy',
#    'and',
#    'her',
#    'mother',
#    ',',
#    'in',
#    'which',
#    'lucy',
#    'admits',
#    'to',
#    'her',
#    'that',
#    'she',
#    'has',
#    'a',
#    'drug',
#    'problem',
#    ',',
#    'and',
#    'her',
#    'mother',
#    'matter',
#    '-',
#    'of',
#    '-',
#    'factly',
#    'responds',
#    'by',
#    'saying',
#    'she',
#    'can',
#    "'",
#    't',
#    'help',
#    'her',
#    ',',
#    'is',
#    'heartbreaking',
#    '.',
#    'although',
#    'not',
#    'autobiographical',
#    ',',
#    'sheedy',
#    'has',
#    'had',
#    'drug',
#    'problems',
#    'in',
#    'her',
#    'past',
#    ',',
#    'and',
#    'i',
#    'suspect',
#    'she',
#    'brought',
#    'that',
#    'knowledge',
#    'of',
#    'already',
#    'being',
#    'in',
#    'lucy',
#    "'",
#    's',
#    'footsteps',
#    'to',
#    'her',
#    'role',
#    '.',
#    'also',
#    'very',
#    'good',
#    'is',
#    'radha',
#    'mitchell',
#    'as',
#    'syd',
#    ',',
#    'who',
#    'previously',
#    'starred',
#    'in',
#    'the',
#    'slight',
#    '1997',
#    'australian',
#    'comedy',
#    ',',
#    '"',
#    'love',
#    'and',
#    'other',
#    'catastrophes',
#    ',',
#    '"',
#    'wh',
#    'caught',
#    'me',
#    'by',
#    'surprise',
#    'with',
#    'her',
#    'performance',
#    '.',
#    'easily',
#    'being',
#    'able',
#    'to',
#    'pass',
#    'as',
#    'christina',
#    'ricci',
#    "'",
#    's',
#    'older',
#    'sister',
#    ',',
#    'mitchell',
#    'obtains',
#    'the',
#    'same',
#    'natural',
#    'charisma',
#    'that',
#    'has',
#    'made',
#    'ricci',
#    'so',
#    'popular',
#    'recently',
#    '.',
#    'as',
#    'accurate',
#    'as',
#    'almost',
#    'every',
#    'detail',
#    'is',
#    'in',
#    ',',
#    '"',
#    'high',
#    'art',
#    ',',
#    '"',
#    'i',
#    'wish',
#    'the',
#    'relationship',
#    'had',
#    'been',
#    'more',
#    'tightly',
#    'written',
#    'involving',
#    'syd',
#    'and',
#    'james',
#    ',',
#    'who',
#    ',',
#    'played',
#    'by',
#    'gabriel',
#    'mann',
#    ',',
#    'is',
#    'left',
#    'with',
#    'a',
#    'throwaway',
#    'role',
#    '.',
#    'by',
#    'the',
#    'time',
#    'he',
#    'finds',
#    'out',
#    'about',
#    'syd',
#    'and',
#    'lucy',
#    ',',
#    'he',
#    'disappears',
#    'from',
#    'the',
#    'film',
#    ',',
#    'and',
#    'i',
#    'wish',
#    'there',
#    'had',
#    'been',
#    'another',
#    'scene',
#    'where',
#    'they',
#    'confronted',
#    'each',
#    'other',
#    '.',
#    'this',
#    'is',
#    'a',
#    'very',
#    'minor',
#    'fault',
#    ',',
#    'however',
#    ',',
#    'in',
#    'a',
#    'film',
#    'that',
#    'is',
#    'full',
#    'of',
#    'riches',
#    '.',
#    'although',
#    'many',
#    'of',
#    'the',
#    'characters',
#    'are',
#    'stuck',
#    'in',
#    'a',
#    'hopeless',
#    'pit',
#    'of',
#    'despair',
#    ',',
#    'syd',
#    'and',
#    'lucy',
#    'are',
#    'intelligent',
#    'people',
#    'who',
#    'recognize',
#    'their',
#    'problems',
#    '.',
#    'the',
#    'character',
#    'of',
#    'dominique',
#    '(',
#    'anh',
#    'duong',
#    ')',
#    ',',
#    'the',
#    '"',
#    'frame',
#    '"',
#    'editor',
#    'who',
#    'decides',
#    'to',
#    'give',
#    'syd',
#    'a',
#    'chance',
#    'with',
#    'her',
#    'ideas',
#    ',',
#    'was',
#    'also',
#    'written',
#    'to',
#    'be',
#    'far',
#    'more',
#    'mature',
#    'than',
#    'expected',
#    '.',
#    'and',
#    'the',
#    'one',
#    'sex',
#    'scene',
#    'in',
#    'the',
#    'film',
#    'was',
#    'beautifully',
#    'and',
#    'originally',
#    'done',
#    '.',
#    'for',
#    'once',
#    ',',
#    'it',
#    'did',
#    'not',
#    'invlove',
#    'steaminess',
#    ',',
#    'or',
#    'violent',
#    'sexual',
#    'activity',
#    ',',
#    'or',
#    'gratuitous',
#    'nudity',
#    ',',
#    'but',
#    'focused',
#    'on',
#    'the',
#    'actual',
#    'characters',
#    ',',
#    'who',
#    'love',
#    'each',
#    'other',
#    ',',
#    'and',
#    'their',
#    'insecurities',
#    'involved',
#    'in',
#    'making',
#    'the',
#    'decision',
#    'to',
#    'actually',
#    'have',
#    'sex',
#    '.',
#    '"',
#    'high',
#    'art',
#    ',',
#    '"',
#    'which',
#    'won',
#    'the',
#    'screenwriting',
#    'award',
#    'at',
#    'the',
#    '1998',
#    'sundance',
#    'film',
#    'festival',
#    ',',
#    'marks',
#    'the',
#    'superior',
#    'feature',
#    'film',
#    'debut',
#    'of',
#    'cholodenko',
#    ',',
#    'as',
#    'well',
#    'as',
#    'sheedy',
#    "'",
#    's',
#    'strongest',
#    ',',
#    'and',
#    'best',
#    ',',
#    'role',
#    'to',
#    'date',
#    '.'],
#   'pos')]

# %% [markdown]
# ## Feature Extraction

# %%
word_features = [word for word in counter_dict.most_common(3000) ]
word_features[:10]
# Out:
# [('film', 9519),
#  ('one', 5853),
#  ('movie', 5774),
#  ('like', 3690),
#  ('even', 2565),
#  ('good', 2411),
#  ('time', 2411),
#  ('story', 2170),
#  ('would', 2110),
#  ('much', 2050)]

# %%
def search_features (doc) :
    words = set(doc)
    features = {}
    for w in word_features:
        features [w] = (w in words)
    return features

# %%
len(docs), docs[0][1], docs[0] [0]
# Out:
# (2000,
#  'neg',
#  ['plot',
#   ':',
#   'two',
#   'teen',
#   'couples',
#   'go',
#   'to',
#   'a',
#   'church',
#   'party',
#   ',',
#   'drink',
#   'and',
#   'then',
#   'drive',
#   '.',
#   'they',
#   'get',
#   'into',
#   'an',
#   'accident',
#   '.',
#   'one',
#   'of',
#   'the',
#   'guys',
#   'dies',
#   ',',
#   'but',
#   'his',
#   'girlfriend',
#   'continues',
#   'to',
#   'see',
#   'him',
#   'in',
#   'her',
#   'life',
#   ',',
#   'and',
#   'has',
#   'nightmares',
#   '.',
#   'what',
#   "'",
#   's',
#   'the',
#   'deal',
#   '?',
#   'watch',
#   'the',
#   'movie',
#   'and',
#   '"',
#   'sorta',
#   '"',
#   'find',
#   'out',
#   '.',
#   '.',
#   '.',
#   'critique',
#   ':',
#   'a',
#   'mind',
#   '-',
#   'fuck',
#   'movie',
#   'for',
#   'the',
#   'teen',
#   'generation',
#   'that',
#   'touches',
#   'on',
#   'a',
#   'very',
#   'cool',
#   'idea',
#   ',',
#   'but',
#   'presents',
#   'it',
#   'in',
#   'a',
#   'very',
#   'bad',
#   'package',
#   '.',
#   'which',
#   'is',
#   'what',
#   'makes',
#   'this',
#   'review',
#   'an',
#   'even',
#   'harder',
#   'one',
#   'to',
#   'write',
#   ',',
#   'since',
#   'i',
#   'generally',
#   'applaud',
#   'films',
#   'which',
#   'attempt',
#   'to',
#   'break',
#   'the',
#   'mold',
#   ',',
#   'mess',
#   'with',
#   'your',
#   'head',
#   'and',
#   'such',
#   '(',
#   'lost',
#   'highway',
#   '&',
#   'memento',
#   ')',
#   ',',
#   'but',
#   'there',
#   'are',
#   'good',
#   'and',
#   'bad',
#   'ways',
#   'of',
#   'making',
#   'all',
#   'types',
#   'of',
#   'films',
#   ',',
#   'and',
#   'these',
#   'folks',
#   'just',
#   'didn',
#   "'",
#   't',
#   'snag',
#   'this',
#   'one',
#   'correctly',
#   '.',
#   'they',
#   'seem',
#   'to',
#   'have',
#   'taken',
#   'this',
#   'pretty',
#   'neat',
#   'concept',
#   ',',
#   'but',
#   'executed',
#   'it',
#   'terribly',
#   '.',
#   'so',
#   'what',
#   'are',
#   'the',
#   'problems',
#   'with',
#   'the',
#   'movie',
#   '?',
#   'well',
#   ',',
#   'its',
#   'main',
#   'problem',
#   'is',
#   'that',
#   'it',
#   "'",
#   's',
#   'simply',
#   'too',
#   'jumbled',
#   '.',
#   'it',
#   'starts',
#   'off',
#   '"',
#   'normal',
#   '"',
#   'but',
#   'then',
#   'downshifts',
#   'into',
#   'this',
#   '"',
#   'fantasy',
#   '"',
#   'world',
#   'in',
#   'which',
#   'you',
#   ',',
#   'as',
#   'an',
#   'audience',
#   'member',
#   ',',
#   'have',
#   'no',
#   'idea',
#   'what',
#   "'",
#   's',
#   'going',
#   'on',
#   '.',
#   'there',
#   'are',
#   'dreams',
#   ',',
#   'there',
#   'are',
#   'characters',
#   'coming',
#   'back',
#   'from',
#   'the',
#   'dead',
#   ',',
#   'there',
#   'are',
#   'others',
#   'who',
#   'look',
#   'like',
#   'the',
#   'dead',
#   ',',
#   'there',
#   'are',
#   'strange',
#   'apparitions',
#   ',',
#   'there',
#   'are',
#   'disappearances',
#   ',',
#   'there',
#   'are',
#   'a',
#   'looooot',
#   'of',
#   'chase',
#   'scenes',
#   ',',
#   'there',
#   'are',
#   'tons',
#   'of',
#   'weird',
#   'things',
#   'that',
#   'happen',
#   ',',
#   'and',
#   'most',
#   'of',
#   'it',
#   'is',
#   'simply',
#   'not',
#   'explained',
#   '.',
#   'now',
#   'i',
#   'personally',
#   'don',
#   "'",
#   't',
#   'mind',
#   'trying',
#   'to',
#   'unravel',
#   'a',
#   'film',
#   'every',
#   'now',
#   'and',
#   'then',
#   ',',
#   'but',
#   'when',
#   'all',
#   'it',
#   'does',
#   'is',
#   'give',
#   'me',
#   'the',
#   'same',
#   'clue',
#   'over',
#   'and',
#   'over',
#   'again',
#   ',',
#   'i',
#   'get',
#   'kind',
#   'of',
#   'fed',
#   'up',
#   'after',
#   'a',
#   'while',
#   ',',
#   'which',
#   'is',
#   'this',
#   'film',
#   "'",
#   's',
#   'biggest',
#   'problem',
#   '.',
#   'it',
#   "'",
#   's',
#   'obviously',
#   'got',
#   'this',
#   'big',
#   'secret',
#   'to',
#   'hide',
#   ',',
#   'but',
#   'it',
#   'seems',
#   'to',
#   'want',
#   'to',
#   'hide',
#   'it',
#   'completely',
#   'until',
#   'its',
#   'final',
#   'five',
#   'minutes',
#   '.',
#   'and',
#   'do',
#   'they',
#   'make',
#   'things',
#   'entertaining',
#   ',',
#   'thrilling',
#   'or',
#   'even',
#   'engaging',
#   ',',
#   'in',
#   'the',
#   'meantime',
#   '?',
#   'not',
#   'really',
#   '.',
#   'the',
#   'sad',
#   'part',
#   'is',
#   'that',
#   'the',
#   'arrow',
#   'and',
#   'i',
#   'both',
#   'dig',
#   'on',
#   'flicks',
#   'like',
#   'this',
#   ',',
#   'so',
#   'we',
#   'actually',
#   'figured',
#   'most',
#   'of',
#   'it',
#   'out',
#   'by',
#   'the',
#   'half',
#   '-',
#   'way',
#   'point',
#   ',',
#   'so',
#   'all',
#   'of',
#   'the',
#   'strangeness',
#   'after',
#   'that',
#   'did',
#   'start',
#   'to',
#   'make',
#   'a',
#   'little',
#   'bit',
#   'of',
#   'sense',
#   ',',
#   'but',
#   'it',
#   'still',
#   'didn',
#   "'",
#   't',
#   'the',
#   'make',
#   'the',
#   'film',
#   'all',
#   'that',
#   'more',
#   'entertaining',
#   '.',
#   'i',
#   'guess',
#   'the',
#   'bottom',
#   'line',
#   'with',
#   'movies',
#   'like',
#   'this',
#   'is',
#   'that',
#   'you',
#   'should',
#   'always',
#   'make',
#   'sure',
#   'that',
#   'the',
#   'audience',
#   'is',
#   '"',
#   'into',
#   'it',
#   '"',
#   'even',
#   'before',
#   'they',
#   'are',
#   'given',
#   'the',
#   'secret',
#   'password',
#   'to',
#   'enter',
#   'your',
#   'world',
#   'of',
#   'understanding',
#   '.',
#   'i',
#   'mean',
#   ',',
#   'showing',
#   'melissa',
#   'sagemiller',
#   'running',
#   'away',
#   'from',
#   'visions',
#   'for',
#   'about',
#   '20',
#   'minutes',
#   'throughout',
#   'the',
#   'movie',
#   'is',
#   'just',
#   'plain',
#   'lazy',
#   '!',
#   '!',
#   'okay',
#   ',',
#   'we',
#   'get',
#   'it',
#   '.',
#   '.',
#   '.',
#   'there',
#   'are',
#   'people',
#   'chasing',
#   'her',
#   'and',
#   'we',
#   'don',
#   "'",
#   't',
#   'know',
#   'who',
#   'they',
#   'are',
#   '.',
#   'do',
#   'we',
#   'really',
#   'need',
#   'to',
#   'see',
#   'it',
#   'over',
#   'and',
#   'over',
#   'again',
#   '?',
#   'how',
#   'about',
#   'giving',
#   'us',
#   'different',
#   'scenes',
#   'offering',
#   'further',
#   'insight',
#   'into',
#   'all',
#   'of',
#   'the',
#   'strangeness',
#   'going',
#   'down',
#   'in',
#   'the',
#   'movie',
#   '?',
#   'apparently',
#   ',',
#   'the',
#   'studio',
#   'took',
#   'this',
#   'film',
#   'away',
#   'from',
#   'its',
#   'director',
#   'and',
#   'chopped',
#   'it',
#   'up',
#   'themselves',
#   ',',
#   'and',
#   'it',
#   'shows',
#   '.',
#   'there',
#   'might',
#   "'",
#   've',
#   'been',
#   'a',
#   'pretty',
#   'decent',
#   'teen',
#   'mind',
#   '-',
#   'fuck',
#   'movie',
#   'in',
#   'here',
#   'somewhere',
#   ',',
#   'but',
#   'i',
#   'guess',
#   '"',
#   'the',
#   'suits',
#   '"',
#   'decided',
#   'that',
#   'turning',
#   'it',
#   'into',
#   'a',
#   'music',
#   'video',
#   'with',
#   'little',
#   'edge',
#   ',',
#   'would',
#   'make',
#   'more',
#   'sense',
#   '.',
#   'the',
#   'actors',
#   'are',
#   'pretty',
#   'good',
#   'for',
#   'the',
#   'most',
#   'part',
#   ',',
#   'although',
#   'wes',
#   'bentley',
#   'just',
#   'seemed',
#   'to',
#   'be',
#   'playing',
#   'the',
#   'exact',
#   'same',
#   'character',
#   'that',
#   'he',
#   'did',
#   'in',
#   'american',
#   'beauty',
#   ',',
#   'only',
#   'in',
#   'a',
#   'new',
#   'neighborhood',
#   '.',
#   'but',
#   'my',
#   'biggest',
#   'kudos',
#   'go',
#   'out',
#   'to',
#   'sagemiller',
#   ',',
#   'who',
#   'holds',
#   'her',
#   'own',
#   'throughout',
#   'the',
#   'entire',
#   'film',
#   ',',
#   'and',
#   'actually',
#   'has',
#   'you',
#   'feeling',
#   'her',
#   'character',
#   "'",
#   's',
#   'unraveling',
#   '.',
#   'overall',
#   ',',
#   'the',
#   'film',
#   'doesn',
#   "'",
#   't',
#   'stick',
#   'because',
#   'it',
#   'doesn',
#   "'",
#   't',
#   'entertain',
#   ',',
#   'it',
#   "'",
#   's',
#   'confusing',
#   ',',
#   'it',
#   'rarely',
#   'excites',
#   'and',
#   'it',
#   'feels',
#   'pretty',
#   'redundant',
#   'for',
#   'most',
#   'of',
#   'its',
#   'runtime',
#   ',',
#   'despite',
#   'a',
#   'pretty',
#   'cool',
#   'ending',
#   'and',
#   'explanation',
#   'to',
#   'all',
#   'of',
#   'the',
#   'craziness',
#   'that',
#   'came',
#   'before',
#   'it',
#   '.',
#   'oh',
#   ',',
#   'and',
#   'by',
#   'the',
#   'way',
#   ',',
#   'this',
#   'is',
#   'not',
#   'a',
#   'horror',
#   'or',
#   'teen',
#   'slasher',
#   'flick',
#   '.',
#   '.',
#   '.',
#   'it',
#   "'",
#   's',
#   'just',
#   'packaged',
#   'to',
#   'look',
#   'that',
#   'way',
#   'because',
#   'someone',
#   'is',
#   'apparently',
#   'assuming',
#   'that',
#   'the',
#   'genre',
#   'is',
#   'still',
#   'hot',
#   'with',
#   'the',
#   'kids',
#   '.',
#   'it',
#   'also',
#   'wrapped',
#   'production',
#   'two',
#   'years',
#   'ago',
#   'and',
#   'has',
#   'been',
#   'sitting',
#   'on',
#   'the',
#   'shelves',
#   'ever',
#   'since',
#   '.',
#   'whatever',
#   '.',
#   '.',
#   '.',
#   'skip',
#   'it',
#   '!',
#   'where',
#   "'",
#   's',
#   'joblo',
#   'coming',
#   'from',
#   '?',
#   'a',
#   'nightmare',
#   'of',
#   'elm',
#   'street',
#   '3',
#   '(',
#   '7',
#   '/',
#   '10',
#   ')',
#   '-',
#   'blair',
#   'witch',
#   '2',
#   '(',
#   '7',
#   '/',
#   '10',
#   ')',
#   '-',
#   'the',
#   'crow',
#   '(',
#   '9',
#   '/',
#   '10',
#   ')',
#   '-',
#   'the',
#   'crow',
#   ':',
#   'salvation',
#   '(',
#   '4',
#   '/',
#   '10',
#   ')',
#   '-',
#   'lost',
#   'highway',
#   '(',
#   '10',
#   '/',
#   '10',
#   ')',
#   '-',
#   'memento',
#   '(',
#   '10',
#   '/',
#   '10',
#   ')',
#   '-',
#   'the',
#   'others',
#   '(',
#   '9',
#   '/',
#   '10',
#   ')',
#   '-',
#   'stir',
#   'of',
#   'echoes',
#   '(',
#   '8',
#   '/',
#   '10',
#   ')'])

# %%
search_features(docs[0][0])
# Out:
# {('film', 9519): False,
#  ('one', 5853): False,
#  ('movie', 5774): False,
#  ('like', 3690): False,
#  ('even', 2565): False,
#  ('good', 2411): False,
#  ('time', 2411): False,
#  ('story', 2170): False,
#  ('would', 2110): False,
#  ('much', 2050): False,
#  ('character', 2020): False,
#  ('also', 1967): False,
#  ('get', 1949): False,
#  ('two', 1912): False,
#  ('well', 1906): False,
#  ('characters', 1859): False,
#  ('first', 1836): False,
#  ('see', 1749): False,
#  ('way', 1693): False,
#  ('make', 1642): False,
#  ('life', 1589): False,
#  ('really', 1565): False,
#  ('films', 1536): False,
#  ('plot', 1513): False,
#  ('little', 1502): False,
#  ('people', 1456): False,
#  ('could', 1427): False,
#  ('scene', 1397): False,
#  ('bad', 1396): False,
#  ('man', 1396): False,
#  ('never', 1375): False,
#  ('best', 1333): False,
#  ('new', 1292): False,
#  ('scenes', 1274): False,
#  ('many', 1269): False,
#  ('director', 1237): False,
#  ('know', 1217): False,
#  ('movies', 1206): False,
#  ('action', 1172): False,
#  ('great', 1149): False,
#  ('another', 1121): False,
#  ('love', 1119): False,
#  ('go', 1113): False,
#  ('made', 1084): False,
#  ('us', 1073): False,
#  ('big', 1064): False,
#  ('end', 1062): False,
#  ('something', 1061): False,
#  ('back', 1060): False,
#  ('still', 1048): False,
#  ('world', 1037): False,
#  ('seems', 1033): False,
#  ('work', 1020): False,
#  ('makes', 992): False,
#  ('however', 989): False,
#  ('every', 947): False,
#  ('though', 940): False,
#  ('better', 922): False,
#  ('real', 920): False,
#  ('audience', 914): False,
#  ('enough', 910): False,
#  ('seen', 910): False,
#  ('take', 905): False,
#  ('around', 903): False,
#  ('going', 888): False,
#  ('year', 886): False,
#  ('performance', 886): False,
#  ('role', 872): False,
#  ('old', 870): False,
#  ('gets', 865): False,
#  ('may', 857): False,
#  ('things', 852): False,
#  ('think', 849): False,
#  ('last', 848): False,
#  ('years', 846): False,
#  ('comedy', 840): False,
#  ('funny', 840): False,
#  ('actually', 837): False,
#  ('long', 837): False,
#  ('look', 835): False,
#  ('almost', 820): False,
#  ('thing', 810): False,
#  ('fact', 805): False,
#  ('nothing', 804): False,
#  ('say', 802): False,
#  ('john', 800): False,
#  ('right', 798): False,
#  ('although', 795): False,
#  ('played', 791): False,
#  ('find', 782): False,
#  ('come', 780): False,
#  ('script', 778): False,
#  ('ever', 776): False,
#  ('cast', 769): False,
#  ('since', 768): False,
#  ('star', 763): False,
#  ('plays', 752): False,
#  ('young', 743): False,
#  ('show', 742): False,
#  ('comes', 733): False,
#  ('part', 714): False,
#  ('original', 713): False,
#  ('actors', 706): False,
#  ('screen', 705): False,
#  ('without', 697): False,
#  ('acting', 695): False,
#  ('three', 695): False,
#  ('day', 688): False,
#  ('point', 685): False,
#  ('lot', 678): False,
#  ('least', 677): False,
#  ('takes', 674): False,
#  ('guy', 664): False,
#  ('quite', 661): False,
#  ('away', 655): False,
#  ('family', 652): False,
#  ('effects', 649): False,
#  ('course', 648): False,
#  ('goes', 646): False,
#  ('minutes', 644): False,
#  ('interesting', 638): False,
#  ('might', 635): False,
#  ('far', 635): False,
#  ('high', 624): False,
#  ('rather', 621): False,
#  ('must', 620): False,
#  ('anything', 619): False,
#  ('place', 615): False,
#  ('set', 610): False,
#  ('yet', 608): False,
#  ('watch', 603): False,
#  ('making', 602): False,
#  ('wife', 588): False,
#  ('hard', 587): False,
#  ('always', 586): False,
#  ('fun', 584): False,
#  ('seem', 574): False,
#  ('special', 574): False,
#  ('bit', 568): False,
#  ('times', 568): False,
#  ('trying', 566): False,
#  ('hollywood', 566): False,
#  ('instead', 565): False,
#  ('give', 561): False,
#  ('want', 560): False,
#  ('picture', 560): False,
#  ('kind', 559): False,
#  ('american', 559): False,
#  ('job', 556): False,
#  ('sense', 555): False,
#  ('woman', 554): False,
#  ('home', 551): False,
#  ('series', 548): False,
#  ('actor', 546): False,
#  ('probably', 539): False,
#  ('help', 537): False,
#  ('half', 535): False,
#  ('men', 533): False,
#  ('along', 533): False,
#  ('everything', 530): False,
#  ('pretty', 528): False,
#  ('becomes', 526): False,
#  ('sure', 523): False,
#  ('black', 523): False,
#  ('together', 522): False,
#  ('dialogue', 519): False,
#  ('money', 512): False,
#  ('become', 511): False,
#  ('gives', 507): False,
#  ('given', 502): False,
#  ('looking', 501): False,
#  ('whole', 496): False,
#  ('watching', 493): False,
#  ('father', 492): False,
#  ('got', 486): False,
#  ('feel', 485): False,
#  ('everyone', 484): False,
#  ('music', 480): False,
#  ('wants', 477): False,
#  ('sex', 476): False,
#  ('less', 475): False,
#  ('done', 475): False,
#  ('horror', 473): False,
#  ('death', 469): False,
#  ('perhaps', 464): False,
#  ('city', 459): False,
#  ('next', 458): False,
#  ('especially', 456): False,
#  ('play', 453): False,
#  ('mind', 452): False,
#  ('girl', 452): False,
#  ('10', 449): False,
#  ('moments', 447): False,
#  ('looks', 444): False,
#  ('completely', 440): False,
#  ('2', 440): False,
#  ('reason', 437): False,
#  ('mother', 437): False,
#  ('whose', 436): False,
#  ('line', 435): False,
#  ('night', 435): False,
#  ('human', 432): False,
#  ('rest', 431): False,
#  ('performances', 431): False,
#  ('different', 430): False,
#  ('evil', 429): False,
#  ('small', 429): False,
#  ('james', 429): False,
#  ('simply', 428): False,
#  ('couple', 427): False,
#  ('put', 426): False,
#  ('let', 425): False,
#  ('anyone', 424): False,
#  ('ending', 423): False,
#  ('case', 420): False,
#  ('dead', 419): False,
#  ('several', 419): False,
#  ('michael', 417): False,
#  ('left', 413): False,
#  ('thought', 413): False,
#  ('school', 411): False,
#  ('shows', 410): False,
#  ('humor', 410): False,
#  ('true', 410): False,
#  ('lost', 409): False,
#  ('written', 409): False,
#  ('friend', 409): False,
#  ('entire', 408): False,
#  ('getting', 406): False,
#  ('town', 404): False,
#  ('turns', 403): False,
#  ('soon', 402): False,
#  ('someone', 401): False,
#  ('second', 401): False,
#  ('main', 399): False,
#  ('stars', 399): False,
#  ('found', 398): False,
#  ('use', 398): False,
#  ('problem', 396): False,
#  ('friends', 396): False,
#  ('tv', 395): False,
#  ('top', 393): False,
#  ('name', 392): False,
#  ('begins', 392): False,
#  ('called', 391): False,
#  ('based', 389): False,
#  ('comic', 389): False,
#  ('david', 388): False,
#  ('head', 387): False,
#  ('else', 387): False,
#  ('idea', 386): False,
#  ('either', 386): False,
#  ('wrong', 385): False,
#  ('unfortunately', 382): False,
#  ('later', 382): False,
#  ('final', 380): False,
#  ('hand', 378): False,
#  ('house', 378): False,
#  ('alien', 378): False,
#  ('group', 377): False,
#  ('full', 375): False,
#  ('used', 372): False,
#  ('tries', 370): False,
#  ('often', 370): False,
#  ('war', 370): False,
#  ('sequence', 366): False,
#  ('keep', 364): False,
#  ('turn', 363): False,
#  ('playing', 362): False,
#  ('boy', 362): False,
#  ('live', 362): False,
#  ('behind', 362): False,
#  ('named', 362): False,
#  ('certainly', 361): False,
#  ('believe', 360): False,
#  ('works', 359): False,
#  ('relationship', 359): False,
#  ('face', 357): False,
#  ('hour', 355): False,
#  ('run', 354): False,
#  ('style', 354): False,
#  ('said', 353): False,
#  ('despite', 352): False,
#  ('person', 352): False,
#  ('finally', 350): False,
#  ('shot', 348): False,
#  ('book', 347): False,
#  ('tell', 346): False,
#  ('maybe', 345): False,
#  ('nice', 344): False,
#  ('son', 343): False,
#  ('perfect', 343): False,
#  ('side', 341): False,
#  ('seeing', 339): False,
#  ('able', 339): False,
#  ('children', 337): False,
#  ('finds', 337): False,
#  ('days', 336): False,
#  ('past', 336): False,
#  ('summer', 334): False,
#  ('camera', 333): False,
#  ('including', 330): False,
#  ('mr', 329): False,
#  ('kids', 328): False,
#  ('lives', 327): False,
#  ('directed', 326): False,
#  ('moment', 325): False,
#  ('game', 325): False,
#  ('running', 323): False,
#  ('fight', 323): False,
#  ('supposed', 323): False,
#  ('video', 322): False,
#  ('car', 321): False,
#  ('matter', 321): False,
#  ('kevin', 321): False,
#  ('joe', 321): False,
#  ('lines', 320): False,
#  ('worth', 319): False,
#  ('daughter', 317): False,
#  ('earth', 317): False,
#  ('starts', 316): False,
#  ('need', 316): False,
#  ('entertaining', 314): False,
#  ('white', 314): False,
#  ('start', 312): False,
#  ('writer', 312): False,
#  ('dark', 312): False,
#  ('short', 310): False,
#  ('self', 309): False,
#  ('worst', 308): False,
#  ('nearly', 307): False,
#  ('opening', 306): False,
#  ('try', 306): False,
#  ('upon', 306): False,
#  ('care', 304): False,
#  ('early', 303): False,
#  ('violence', 303): False,
#  ('throughout', 302): False,
#  ('team', 302): False,
#  ('beautiful', 301): False,
#  ('production', 300): False,
#  ('example', 300): False,
#  ('exactly', 298): False,
#  ('title', 297): False,
#  ('jack', 297): False,
#  ('review', 295): False,
#  ('major', 295): False,
#  ('drama', 294): False,
#  ('problems', 293): False,
#  ('sequences', 293): False,
#  ('obvious', 292): False,
#  ('version', 292): False,
#  ('screenplay', 292): False,
#  ('known', 292): False,
#  ('killer', 291): False,
#  ('robert', 291): False,
#  ('disney', 290): False,
#  ('already', 289): False,
#  ('close', 289): False,
#  ('classic', 289): False,
#  ('others', 288): False,
#  ('hit', 285): False,
#  ('kill', 285): False,
#  ('deep', 285): False,
#  ('five', 284): False,
#  ('order', 284): False,
#  ('heart', 284): False,
#  ('act', 284): False,
#  ('simple', 284): False,
#  ('fine', 284): False,
#  ('roles', 283): False,
#  ('four', 283): False,
#  ('jackie', 283): False,
#  ('direction', 283): False,
#  ('eyes', 282): False,
#  ('question', 278): False,
#  ('sort', 278): False,
#  ('sometimes', 277): False,
#  ('knows', 277): False,
#  ('women', 276): False,
#  ('supporting', 276): False,
#  ('coming', 275): False,
#  ('voice', 275): False,
#  ('truly', 274): False,
#  ('save', 273): False,
#  ('jokes', 273): False,
#  ('computer', 273): False,
#  ('child', 272): False,
#  ('boring', 270): False,
#  ('tom', 270): False,
#  ('level', 270): False,
#  ('1', 270): False,
#  ('scream', 270): False,
#  ('body', 269): False,
#  ('guys', 268): False,
#  ('genre', 268): False,
#  ('brother', 268): False,
#  ('strong', 268): False,
#  ('stop', 268): False,
#  ('room', 268): False,
#  ('space', 267): False,
#  ('lee', 266): False,
#  ('ends', 266): False,
#  ('beginning', 265): False,
#  ('york', 265): False,
#  ('ship', 264): False,
#  ('attempt', 263): False,
#  ('thriller', 263): False,
#  ('peter', 261): False,
#  ('husband', 260): False,
#  ('hope', 259): False,
#  ('fiction', 258): False,
#  ('happens', 258): False,
#  ('hero', 258): False,
#  ('novel', 257): False,
#  ('note', 257): False,
#  ('king', 256): False,
#  ('yes', 256): False,
#  ('says', 256): False,
#  ('dog', 256): False,
#  ('tells', 255): False,
#  ('quickly', 255): False,
#  ('romantic', 254): False,
#  ('oscar', 254): False,
#  ('stupid', 253): False,
#  ('possible', 253): False,
#  ('saw', 253): False,
#  ('lead', 251): False,
#  ('murder', 251): False,
#  ('career', 251): False,
#  ('extremely', 248): False,
#  ('manages', 248): False,
#  ('god', 248): False,
#  ('mostly', 247): False,
#  ('wonder', 247): False,
#  ('particularly', 246): False,
#  ('future', 246): False,
#  ('fans', 245): False,
#  ('sound', 245): False,
#  ('worse', 245): False,
#  ('piece', 244): False,
#  ('involving', 244): False,
#  ('de', 244): False,
#  ('appears', 243): False,
#  ('planet', 243): False,
#  ('paul', 243): False,
#  ('involved', 243): False,
#  ('mean', 242): False,
#  ('none', 242): False,
#  ('taking', 242): False,
#  ('hours', 242): False,
#  ('laugh', 242): False,
#  ('police', 241): False,
#  ('sets', 241): False,
#  ('attention', 241): False,
#  ('co', 241): False,
#  ('hell', 240): False,
#  ('eventually', 240): False,
#  ('single', 239): False,
#  ('fall', 239): False,
#  ('falls', 239): False,
#  ('material', 239): False,
#  ('emotional', 239): False,
#  ('power', 238): False,
#  ('late', 238): False,
#  ('lack', 237): False,
#  ('dr', 237): False,
#  ('van', 237): False,
#  ('result', 237): False,
#  ('elements', 236): False,
#  ('experience', 236): False,
#  ('meet', 236): False,
#  ('smith', 236): False,
#  ('science', 235): False,
#  ('bring', 235): False,
#  ('wild', 235): False,
#  ('living', 234): False,
#  ('theater', 234): False,
#  ('interest', 232): False,
#  ('leads', 231): False,
#  ('word', 231): False,
#  ('feature', 230): False,
#  ('battle', 230): False,
#  ('alone', 230): False,
#  ('girls', 229): False,
#  ('obviously', 228): False,
#  ('george', 228): False,
#  ('within', 227): False,
#  ('usually', 227): False,
#  ('enjoy', 227): False,
#  ('guess', 226): False,
#  ('among', 226): False,
#  ('taken', 225): False,
#  ('feeling', 225): False,
#  ('laughs', 225): False,
#  ('aliens', 225): False,
#  ('talk', 224): False,
#  ('chance', 223): False,
#  ('talent', 223): False,
#  ('3', 222): False,
#  ('middle', 222): False,
#  ('number', 222): False,
#  ('easy', 222): False,
#  ('happen', 221): False,
#  ('across', 221): False,
#  ('needs', 221): False,
#  ('attempts', 221): False,
#  ('television', 220): False,
#  ('chris', 220): False,
#  ('deal', 219): False,
#  ('poor', 219): False,
#  ('form', 219): False,
#  ('girlfriend', 218): False,
#  ('viewer', 218): False,
#  ('release', 218): False,
#  ('killed', 218): False,
#  ('forced', 218): False,
#  ('whether', 217): False,
#  ('wonderful', 217): False,
#  ('feels', 216): False,
#  ('oh', 216): False,
#  ('tale', 216): False,
#  ('serious', 216): False,
#  ('leave', 216): False,
#  ('expect', 216): False,
#  ('except', 216): False,
#  ('light', 216): False,
#  ('success', 216): False,
#  ('features', 216): False,
#  ('premise', 216): False,
#  ('happy', 215): False,
#  ('words', 215): False,
#  ('important', 215): False,
#  ('meets', 215): False,
#  ('history', 215): False,
#  ('ryan', 215): False,
#  ('giving', 214): False,
#  ('crew', 214): False,
#  ('type', 214): False,
#  ('call', 214): False,
#  ('turned', 214): False,
#  ('released', 214): False,
#  ('parents', 214): False,
#  ('art', 214): False,
#  ('impressive', 214): False,
#  ('mission', 213): False,
#  ('working', 213): False,
#  ('seemed', 212): False,
#  ('score', 212): False,
#  ('told', 212): False,
#  ('america', 212): False,
#  ('recent', 211): False,
#  ('robin', 211): False,
#  ('basically', 211): False,
#  ('entertainment', 211): False,
#  ('surprise', 210): False,
#  ('apparently', 209): False,
#  ('easily', 209): False,
#  ('cool', 208): False,
#  ('stuff', 208): False,
#  ('cop', 208): False,
#  ('change', 208): False,
#  ('williams', 208): False,
#  ('crime', 208): False,
#  ('office', 208): False,
#  ('parts', 207): False,
#  ('somehow', 207): False,
#  ('sequel', 207): False,
#  ('william', 206): False,
#  ('cut', 206): False,
#  ('die', 205): False,
#  ('jones', 204): False,
#  ('credits', 203): False,
#  ('batman', 203): False,
#  ('suspense', 202): False,
#  ('brings', 202): False,
#  ('reality', 202): False,
#  ('events', 201): False,
#  ('local', 201): False,
#  ('talking', 200): False,
#  ('difficult', 200): False,
#  ('using', 200): False,
#  ('went', 200): False,
#  ('writing', 200): False,
#  ('remember', 200): False,
#  ('near', 200): False,
#  ('straight', 200): False,
#  ('hilarious', 200): False,
#  ('ago', 199): False,
#  ('certain', 199): False,
#  ('ben', 199): False,
#  ('red', 198): False,
#  ('kid', 198): False,
#  ('slow', 198): False,
#  ('blood', 198): False,
#  ('mystery', 198): False,
#  ('complete', 197): False,
#  ('popular', 197): False,
#  ('effective', 197): False,
#  ('fast', 197): False,
#  ('flick', 196): False,
#  ('due', 196): False,
#  ('runs', 196): False,
#  ('gone', 195): False,
#  ('return', 195): False,
#  ('presence', 195): False,
#  ('quality', 195): False,
#  ('dramatic', 194): False,
#  ('filmmakers', 194): False,
#  ('age', 194): False,
#  ('brothers', 194): False,
#  ('business', 193): False,
#  ('general', 193): False,
#  ('rock', 192): False,
#  ('sexual', 192): False,
#  ('present', 192): False,
#  ('surprisingly', 191): False,
#  ('anyway', 191): False,
#  ('uses', 191): False,
#  ('4', 190): False,
#  ('personal', 190): False,
#  ('figure', 190): False,
#  ('smart', 190): False,
#  ('ways', 189): False,
#  ('decides', 189): False,
#  ('annoying', 189): False,
#  ('begin', 189): False,
#  ('somewhat', 188): False,
#  ('shots', 188): False,
#  ('rich', 188): False,
#  ('minute', 187): False,
#  ('law', 187): False,
#  ('previous', 186): False,
#  ('jim', 186): False,
#  ('successful', 186): False,
#  ('harry', 186): False,
#  ('water', 186): False,
#  ('similar', 186): False,
#  ('absolutely', 186): False,
#  ('motion', 186): False,
#  ('former', 186): False,
#  ('strange', 185): False,
#  ('came', 185): False,
#  ('follow', 185): False,
#  ('read', 185): False,
#  ('project', 185): False,
#  ('million', 185): False,
#  ('secret', 184): False,
#  ('starring', 184): False,
#  ('clear', 184): False,
#  ('familiar', 184): False,
#  ('eye', 184): False,
#  ('romance', 184): False,
#  ('intelligent', 184): False,
#  ('third', 184): False,
#  ('excellent', 184): False,
#  ('amazing', 184): False,
#  ('party', 183): False,
#  ('budget', 183): False,
#  ('actress', 183): False,
#  ('prison', 183): False,
#  ('latest', 183): False,
#  ('means', 183): False,
#  ('company', 183): False,
#  ('towards', 182): False,
#  ('predictable', 182): False,
#  ('powerful', 182): False,
#  ('bob', 182): False,
#  ('beyond', 181): False,
#  ('visual', 181): False,
#  ('leaves', 181): False,
#  ('r', 180): False,
#  ('nature', 180): False,
#  ('following', 180): False,
#  ('villain', 180): False,
#  ('leaving', 180): False,
#  ('wars', 180): False,
#  ('animated', 179): False,
#  ('low', 179): False,
#  ('b', 179): False,
#  ('bill', 179): False,
#  ('sam', 179): False,
#  ('filled', 179): False,
#  ('questions', 178): False,
#  ('cinema', 178): False,
#  ('message', 178): False,
#  ('box', 178): False,
#  ('moving', 178): False,
#  ('country', 178): False,
#  ('usual', 177): False,
#  ('martin', 177): False,
#  ('definitely', 177): False,
#  ('add', 177): False,
#  ('large', 177): False,
#  ('clever', 177): False,
#  ('create', 177): False,
#  ('felt', 176): False,
#  ('stories', 176): False,
#  ('brilliant', 176): False,
#  ('ones', 176): False,
#  ('giant', 176): False,
#  ('situation', 176): False,
#  ('murphy', 176): False,
#  ('break', 175): False,
#  ('opens', 175): False,
#  ('scary', 175): False,
#  ('doubt', 175): False,
#  ('drug', 175): False,
#  ('bunch', 174): False,
#  ('thinking', 174): False,
#  ('solid', 174): False,
#  ('effect', 173): False,
#  ('learn', 172): False,
#  ('move', 172): False,
#  ('force', 171): False,
#  ('potential', 171): False,
#  ('seriously', 171): False,
#  ('follows', 170): False,
#  ('huge', 170): False,
#  ('saying', 170): False,
#  ('class', 169): False,
#  ('plan', 169): False,
#  ('agent', 168): False,
#  ('created', 167): False,
#  ('unlike', 167): False,
#  ('pay', 166): False,
#  ('non', 166): False,
#  ('married', 166): False,
#  ('mark', 166): False,
#  ('sweet', 166): False,
#  ('perfectly', 166): False,
#  ('ex', 165): False,
#  ('realize', 165): False,
#  ('audiences', 165): False,
#  ('took', 164): False,
#  ('decent', 164): False,
#  ('likely', 164): False,
#  ('dream', 164): False,
#  ('view', 164): False,
#  ('scott', 164): False,
#  ('subject', 164): False,
#  ('understand', 164): False,
#  ('happened', 164): False,
#  ('enjoyable', 164): False,
#  ('studio', 163): False,
#  ('immediately', 163): False,
#  ('open', 163): False,
#  ('e', 163): False,
#  ('points', 163): False,
#  ('heard', 163): False,
#  ('viewers', 163): False,
#  ('cameron', 163): False,
#  ('truman', 163): False,
#  ('bruce', 162): False,
#  ('frank', 162): False,
#  ('private', 161): False,
#  ('stay', 161): False,
#  ('fails', 161): False,
#  ('impossible', 161): False,
#  ('cold', 161): False,
#  ('richard', 161): False,
#  ('overall', 160): False,
#  ('merely', 160): False,
#  ('exciting', 160): False,
#  ('mess', 159): False,
#  ('chase', 159): False,
#  ('escape', 159): False,
#  ('free', 159): False,
#  ('ten', 159): False,
#  ('neither', 159): False,
#  ('wanted', 159): False,
#  ('gun', 159): False,
#  ('appear', 159): False,
#  ('carter', 159): False,
#  ('ultimately', 158): False,
#  ('fan', 158): False,
#  ('inside', 157): False,
#  ('favorite', 157): False,
#  ('modern', 157): False,
#  ('l', 157): False,
#  ('wedding', 157): False,
#  ('stone', 157): False,
#  ('trek', 157): False,
#  ('brought', 157): False,
#  ('trouble', 157): False,
#  ('otherwise', 156): False,
#  ('tim', 156): False,
#  ('5', 156): False,
#  ('allen', 156): False,
#  ('bond', 155): False,
#  ('society', 155): False,
#  ('liked', 155): False,
#  ('dumb', 155): False,
#  ('musical', 154): False,
#  ('stand', 154): False,
#  ('political', 154): False,
#  ('various', 154): False,
#  ('talented', 154): False,
#  ('particular', 154): False,
#  ('west', 154): False,
#  ('state', 153): False,
#  ('keeps', 153): False,
#  ('english', 152): False,
#  ('silly', 152): False,
#  ('u', 152): False,
#  ('situations', 152): False,
#  ('park', 152): False,
#  ('teen', 151): False,
#  ('rating', 151): False,
#  ('slightly', 151): False,
#  ('steve', 151): False,
#  ('truth', 151): False,
#  ('air', 151): False,
#  ('element', 150): False,
#  ('joke', 150): False,
#  ('spend', 150): False,
#  ('key', 150): False,
#  ('biggest', 149): False,
#  ('members', 149): False,
#  ('effort', 149): False,
#  ('government', 149): False,
#  ('focus', 149): False,
#  ('today', 149): False,
#  ('eddie', 149): False,
#  ('soundtrack', 148): False,
#  ('hands', 148): False,
#  ('earlier', 148): False,
#  ('chan', 148): False,
#  ('purpose', 148): False,
#  ('showing', 147): False,
#  ('memorable', 147): False,
#  ('six', 147): False,
#  ('max', 147): False,
#  ('offers', 147): False,
#  ('rated', 146): False,
#  ('mars', 146): False,
#  ('heavy', 146): False,
#  ('totally', 146): False,
#  ('control', 145): False,
#  ('credit', 145): False,
#  ('fi', 145): False,
#  ('woody', 145): False,
#  ('ideas', 144): False,
#  ('sci', 144): False,
#  ('wait', 144): False,
#  ('sit', 144): False,
#  ('female', 143): False,
#  ('ask', 143): False,
#  ('waste', 143): False,
#  ('terrible', 143): False,
#  ('depth', 143): False,
#  ('simon', 143): False,
#  ('aspect', 143): False,
#  ('list', 143): False,
#  ('mary', 143): False,
#  ('sister', 143): False,
#  ('animation', 142): False,
#  ('entirely', 142): False,
#  ('fear', 142): False,
#  ('steven', 142): False,
#  ('moves', 142): False,
#  ('actual', 142): False,
#  ('army', 142): False,
#  ('british', 142): False,
#  ('constantly', 142): False,
#  ('fire', 142): False,
#  ('convincing', 141): False,
#  ('setting', 141): False,
#  ('gave', 141): False,
#  ('tension', 141): False,
#  ('street', 140): False,
#  ('8', 140): False,
#  ('brief', 140): False,
#  ('ridiculous', 140): False,
#  ('cinematography', 140): False,
#  ('typical', 140): False,
#  ('nick', 140): False,
#  ('screenwriter', 140): False,
#  ('ability', 140): False,
#  ('spent', 140): False,
#  ('quick', 139): False,
#  ('violent', 139): False,
#  ('atmosphere', 139): False,
#  ('subtle', 139): False,
#  ('expected', 138): False,
#  ('fairly', 138): False,
#  ('seven', 138): False,
#  ('disaster', 138): False,
#  ('killing', 138): False,
#  ('tone', 138): False,
#  ('master', 138): False,
#  ('highly', 137): False,
#  ('lots', 137): False,
#  ('thinks', 137): False,
#  ('song', 137): False,
#  ('cheap', 137): False,
#  ('suddenly', 137): False,
#  ('background', 137): False,
#  ('club', 137): False,
#  ('willis', 137): False,
#  ('whatever', 136): False,
#  ('sees', 136): False,
#  ('complex', 136): False,
#  ('greatest', 136): False,
#  ('impact', 136): False,
#  ('ii', 136): False,
#  ('beauty', 135): False,
#  ('front', 135): False,
#  ('humans', 135): False,
#  ('indeed', 135): False,
#  ('flat', 135): False,
#  ('grace', 135): False,
#  ('wrote', 135): False,
#  ('amusing', 135): False,
#  ('titanic', 135): False,
#  ('mike', 135): False,
#  ('cute', 134): False,
#  ('dull', 134): False,
#  ('minor', 134): False,
#  ('recently', 134): False,
#  ('hate', 134): False,
#  ('outside', 134): False,
#  ('plenty', 134): False,
#  ('wish', 134): False,
#  ('godzilla', 134): False,
#  ('college', 134): False,
#  ('sounds', 133): False,
#  ('telling', 133): False,
#  ('sight', 133): False,
#  ('double', 133): False,
#  ('cinematic', 133): False,
#  ('queen', 133): False,
#  ('hold', 133): False,
#  ('meanwhile', 133): False,
#  ('awful', 132): False,
#  ('clearly', 132): False,
#  ('theme', 132): False,
#  ('hear', 132): False,
#  ('x', 132): False,
#  ('amount', 132): False,
#  ('baby', 132): False,
#  ('approach', 132): False,
#  ('dreams', 131): False,
#  ('shown', 131): False,
#  ('island', 131): False,
#  ('reasons', 131): False,
#  ('charm', 131): False,
#  ('miss', 131): False,
#  ('longer', 131): False,
#  ('common', 130): False,
#  ('sean', 130): False,
#  ('carry', 130): False,
#  ('believable', 130): False,
#  ('realistic', 130): False,
#  ('chemistry', 130): False,
#  ('possibly', 129): False,
#  ('casting', 129): False,
#  ('somewhere', 128): False,
#  ('carrey', 128): False,
#  ('french', 128): False,
#  ('trailer', 128): False,
#  ('tough', 128): False,
#  ('produced', 128): False,
#  ('imagine', 128): False,
#  ('choice', 128): False,
#  ('ride', 128): False,
#  ('hot', 127): False,
#  ('race', 127): False,
#  ('road', 127): False,
#  ('leader', 127): False,
#  ('thin', 127): False,
#  ('jerry', 127): False,
#  ('slowly', 127): False,
#  ('delivers', 127): False,
#  ('detective', 127): False,
#  ('brown', 127): False,
#  ('jackson', 127): False,
#  ('member', 126): False,
#  ('provide', 126): False,
#  ('president', 126): False,
#  ('puts', 126): False,
#  ('asks', 126): False,
#  ('critics', 126): False,
#  ('appearance', 126): False,
#  ('famous', 126): False,
#  ('okay', 125): False,
#  ('intelligence', 125): False,
#  ('energy', 125): False,
#  ('sent', 125): False,
#  ('spielberg', 125): False,
#  ('development', 125): False,
#  ('etc', 125): False,
#  ('language', 125): False,
#  ('blue', 125): False,
#  ('proves', 125): False,
#  ('vampire', 125): False,
#  ('seemingly', 124): False,
#  ('basic', 124): False,
#  ('caught', 124): False,
#  ('decide', 124): False,
#  ...}

# %%
featureSet = [(search_features(doc), category) for (doc, category) in docs]
featureSet[0]
# Out:
# ({('film', 9519): False,
#   ('one', 5853): False,
#   ('movie', 5774): False,
#   ('like', 3690): False,
#   ('even', 2565): False,
#   ('good', 2411): False,
#   ('time', 2411): False,
#   ('story', 2170): False,
#   ('would', 2110): False,
#   ('much', 2050): False,
#   ('character', 2020): False,
#   ('also', 1967): False,
#   ('get', 1949): False,
#   ('two', 1912): False,
#   ('well', 1906): False,
#   ('characters', 1859): False,
#   ('first', 1836): False,
#   ('see', 1749): False,
#   ('way', 1693): False,
#   ('make', 1642): False,
#   ('life', 1589): False,
#   ('really', 1565): False,
#   ('films', 1536): False,
#   ('plot', 1513): False,
#   ('little', 1502): False,
#   ('people', 1456): False,
#   ('could', 1427): False,
#   ('scene', 1397): False,
#   ('bad', 1396): False,
#   ('man', 1396): False,
#   ('never', 1375): False,
#   ('best', 1333): False,
#   ('new', 1292): False,
#   ('scenes', 1274): False,
#   ('many', 1269): False,
#   ('director', 1237): False,
#   ('know', 1217): False,
#   ('movies', 1206): False,
#   ('action', 1172): False,
#   ('great', 1149): False,
#   ('another', 1121): False,
#   ('love', 1119): False,
#   ('go', 1113): False,
#   ('made', 1084): False,
#   ('us', 1073): False,
#   ('big', 1064): False,
#   ('end', 1062): False,
#   ('something', 1061): False,
#   ('back', 1060): False,
#   ('still', 1048): False,
#   ('world', 1037): False,
#   ('seems', 1033): False,
#   ('work', 1020): False,
#   ('makes', 992): False,
#   ('however', 989): False,
#   ('every', 947): False,
#   ('though', 940): False,
#   ('better', 922): False,
#   ('real', 920): False,
#   ('audience', 914): False,
#   ('enough', 910): False,
#   ('seen', 910): False,
#   ('take', 905): False,
#   ('around', 903): False,
#   ('going', 888): False,
#   ('year', 886): False,
#   ('performance', 886): False,
#   ('role', 872): False,
#   ('old', 870): False,
#   ('gets', 865): False,
#   ('may', 857): False,
#   ('things', 852): False,
#   ('think', 849): False,
#   ('last', 848): False,
#   ('years', 846): False,
#   ('comedy', 840): False,
#   ('funny', 840): False,
#   ('actually', 837): False,
#   ('long', 837): False,
#   ('look', 835): False,
#   ('almost', 820): False,
#   ('thing', 810): False,
#   ('fact', 805): False,
#   ('nothing', 804): False,
#   ('say', 802): False,
#   ('john', 800): False,
#   ('right', 798): False,
#   ('although', 795): False,
#   ('played', 791): False,
#   ('find', 782): False,
#   ('come', 780): False,
#   ('script', 778): False,
#   ('ever', 776): False,
#   ('cast', 769): False,
#   ('since', 768): False,
#   ('star', 763): False,
#   ('plays', 752): False,
#   ('young', 743): False,
#   ('show', 742): False,
#   ('comes', 733): False,
#   ('part', 714): False,
#   ('original', 713): False,
#   ('actors', 706): False,
#   ('screen', 705): False,
#   ('without', 697): False,
#   ('acting', 695): False,
#   ('three', 695): False,
#   ('day', 688): False,
#   ('point', 685): False,
#   ('lot', 678): False,
#   ('least', 677): False,
#   ('takes', 674): False,
#   ('guy', 664): False,
#   ('quite', 661): False,
#   ('away', 655): False,
#   ('family', 652): False,
#   ('effects', 649): False,
#   ('course', 648): False,
#   ('goes', 646): False,
#   ('minutes', 644): False,
#   ('interesting', 638): False,
#   ('might', 635): False,
#   ('far', 635): False,
#   ('high', 624): False,
#   ('rather', 621): False,
#   ('must', 620): False,
#   ('anything', 619): False,
#   ('place', 615): False,
#   ('set', 610): False,
#   ('yet', 608): False,
#   ('watch', 603): False,
#   ('making', 602): False,
#   ('wife', 588): False,
#   ('hard', 587): False,
#   ('always', 586): False,
#   ('fun', 584): False,
#   ('seem', 574): False,
#   ('special', 574): False,
#   ('bit', 568): False,
#   ('times', 568): False,
#   ('trying', 566): False,
#   ('hollywood', 566): False,
#   ('instead', 565): False,
#   ('give', 561): False,
#   ('want', 560): False,
#   ('picture', 560): False,
#   ('kind', 559): False,
#   ('american', 559): False,
#   ('job', 556): False,
#   ('sense', 555): False,
#   ('woman', 554): False,
#   ('home', 551): False,
#   ('series', 548): False,
#   ('actor', 546): False,
#   ('probably', 539): False,
#   ('help', 537): False,
#   ('half', 535): False,
#   ('men', 533): False,
#   ('along', 533): False,
#   ('everything', 530): False,
#   ('pretty', 528): False,
#   ('becomes', 526): False,
#   ('sure', 523): False,
#   ('black', 523): False,
#   ('together', 522): False,
#   ('dialogue', 519): False,
#   ('money', 512): False,
#   ('become', 511): False,
#   ('gives', 507): False,
#   ('given', 502): False,
#   ('looking', 501): False,
#   ('whole', 496): False,
#   ('watching', 493): False,
#   ('father', 492): False,
#   ('got', 486): False,
#   ('feel', 485): False,
#   ('everyone', 484): False,
#   ('music', 480): False,
#   ('wants', 477): False,
#   ('sex', 476): False,
#   ('less', 475): False,
#   ('done', 475): False,
#   ('horror', 473): False,
#   ('death', 469): False,
#   ('perhaps', 464): False,
#   ('city', 459): False,
#   ('next', 458): False,
#   ('especially', 456): False,
#   ('play', 453): False,
#   ('mind', 452): False,
#   ('girl', 452): False,
#   ('10', 449): False,
#   ('moments', 447): False,
#   ('looks', 444): False,
#   ('completely', 440): False,
#   ('2', 440): False,
#   ('reason', 437): False,
#   ('mother', 437): False,
#   ('whose', 436): False,
#   ('line', 435): False,
#   ('night', 435): False,
#   ('human', 432): False,
#   ('rest', 431): False,
#   ('performances', 431): False,
#   ('different', 430): False,
#   ('evil', 429): False,
#   ('small', 429): False,
#   ('james', 429): False,
#   ('simply', 428): False,
#   ('couple', 427): False,
#   ('put', 426): False,
#   ('let', 425): False,
#   ('anyone', 424): False,
#   ('ending', 423): False,
#   ('case', 420): False,
#   ('dead', 419): False,
#   ('several', 419): False,
#   ('michael', 417): False,
#   ('left', 413): False,
#   ('thought', 413): False,
#   ('school', 411): False,
#   ('shows', 410): False,
#   ('humor', 410): False,
#   ('true', 410): False,
#   ('lost', 409): False,
#   ('written', 409): False,
#   ('friend', 409): False,
#   ('entire', 408): False,
#   ('getting', 406): False,
#   ('town', 404): False,
#   ('turns', 403): False,
#   ('soon', 402): False,
#   ('someone', 401): False,
#   ('second', 401): False,
#   ('main', 399): False,
#   ('stars', 399): False,
#   ('found', 398): False,
#   ('use', 398): False,
#   ('problem', 396): False,
#   ('friends', 396): False,
#   ('tv', 395): False,
#   ('top', 393): False,
#   ('name', 392): False,
#   ('begins', 392): False,
#   ('called', 391): False,
#   ('based', 389): False,
#   ('comic', 389): False,
#   ('david', 388): False,
#   ('head', 387): False,
#   ('else', 387): False,
#   ('idea', 386): False,
#   ('either', 386): False,
#   ('wrong', 385): False,
#   ('unfortunately', 382): False,
#   ('later', 382): False,
#   ('final', 380): False,
#   ('hand', 378): False,
#   ('house', 378): False,
#   ('alien', 378): False,
#   ('group', 377): False,
#   ('full', 375): False,
#   ('used', 372): False,
#   ('tries', 370): False,
#   ('often', 370): False,
#   ('war', 370): False,
#   ('sequence', 366): False,
#   ('keep', 364): False,
#   ('turn', 363): False,
#   ('playing', 362): False,
#   ('boy', 362): False,
#   ('live', 362): False,
#   ('behind', 362): False,
#   ('named', 362): False,
#   ('certainly', 361): False,
#   ('believe', 360): False,
#   ('works', 359): False,
#   ('relationship', 359): False,
#   ('face', 357): False,
#   ('hour', 355): False,
#   ('run', 354): False,
#   ('style', 354): False,
#   ('said', 353): False,
#   ('despite', 352): False,
#   ('person', 352): False,
#   ('finally', 350): False,
#   ('shot', 348): False,
#   ('book', 347): False,
#   ('tell', 346): False,
#   ('maybe', 345): False,
#   ('nice', 344): False,
#   ('son', 343): False,
#   ('perfect', 343): False,
#   ('side', 341): False,
#   ('seeing', 339): False,
#   ('able', 339): False,
#   ('children', 337): False,
#   ('finds', 337): False,
#   ('days', 336): False,
#   ('past', 336): False,
#   ('summer', 334): False,
#   ('camera', 333): False,
#   ('including', 330): False,
#   ('mr', 329): False,
#   ('kids', 328): False,
#   ('lives', 327): False,
#   ('directed', 326): False,
#   ('moment', 325): False,
#   ('game', 325): False,
#   ('running', 323): False,
#   ('fight', 323): False,
#   ('supposed', 323): False,
#   ('video', 322): False,
#   ('car', 321): False,
#   ('matter', 321): False,
#   ('kevin', 321): False,
#   ('joe', 321): False,
#   ('lines', 320): False,
#   ('worth', 319): False,
#   ('daughter', 317): False,
#   ('earth', 317): False,
#   ('starts', 316): False,
#   ('need', 316): False,
#   ('entertaining', 314): False,
#   ('white', 314): False,
#   ('start', 312): False,
#   ('writer', 312): False,
#   ('dark', 312): False,
#   ('short', 310): False,
#   ('self', 309): False,
#   ('worst', 308): False,
#   ('nearly', 307): False,
#   ('opening', 306): False,
#   ('try', 306): False,
#   ('upon', 306): False,
#   ('care', 304): False,
#   ('early', 303): False,
#   ('violence', 303): False,
#   ('throughout', 302): False,
#   ('team', 302): False,
#   ('beautiful', 301): False,
#   ('production', 300): False,
#   ('example', 300): False,
#   ('exactly', 298): False,
#   ('title', 297): False,
#   ('jack', 297): False,
#   ('review', 295): False,
#   ('major', 295): False,
#   ('drama', 294): False,
#   ('problems', 293): False,
#   ('sequences', 293): False,
#   ('obvious', 292): False,
#   ('version', 292): False,
#   ('screenplay', 292): False,
#   ('known', 292): False,
#   ('killer', 291): False,
#   ('robert', 291): False,
#   ('disney', 290): False,
#   ('already', 289): False,
#   ('close', 289): False,
#   ('classic', 289): False,
#   ('others', 288): False,
#   ('hit', 285): False,
#   ('kill', 285): False,
#   ('deep', 285): False,
#   ('five', 284): False,
#   ('order', 284): False,
#   ('heart', 284): False,
#   ('act', 284): False,
#   ('simple', 284): False,
#   ('fine', 284): False,
#   ('roles', 283): False,
#   ('four', 283): False,
#   ('jackie', 283): False,
#   ('direction', 283): False,
#   ('eyes', 282): False,
#   ('question', 278): False,
#   ('sort', 278): False,
#   ('sometimes', 277): False,
#   ('knows', 277): False,
#   ('women', 276): False,
#   ('supporting', 276): False,
#   ('coming', 275): False,
#   ('voice', 275): False,
#   ('truly', 274): False,
#   ('save', 273): False,
#   ('jokes', 273): False,
#   ('computer', 273): False,
#   ('child', 272): False,
#   ('boring', 270): False,
#   ('tom', 270): False,
#   ('level', 270): False,
#   ('1', 270): False,
#   ('scream', 270): False,
#   ('body', 269): False,
#   ('guys', 268): False,
#   ('genre', 268): False,
#   ('brother', 268): False,
#   ('strong', 268): False,
#   ('stop', 268): False,
#   ('room', 268): False,
#   ('space', 267): False,
#   ('lee', 266): False,
#   ('ends', 266): False,
#   ('beginning', 265): False,
#   ('york', 265): False,
#   ('ship', 264): False,
#   ('attempt', 263): False,
#   ('thriller', 263): False,
#   ('peter', 261): False,
#   ('husband', 260): False,
#   ('hope', 259): False,
#   ('fiction', 258): False,
#   ('happens', 258): False,
#   ('hero', 258): False,
#   ('novel', 257): False,
#   ('note', 257): False,
#   ('king', 256): False,
#   ('yes', 256): False,
#   ('says', 256): False,
#   ('dog', 256): False,
#   ('tells', 255): False,
#   ('quickly', 255): False,
#   ('romantic', 254): False,
#   ('oscar', 254): False,
#   ('stupid', 253): False,
#   ('possible', 253): False,
#   ('saw', 253): False,
#   ('lead', 251): False,
#   ('murder', 251): False,
#   ('career', 251): False,
#   ('extremely', 248): False,
#   ('manages', 248): False,
#   ('god', 248): False,
#   ('mostly', 247): False,
#   ('wonder', 247): False,
#   ('particularly', 246): False,
#   ('future', 246): False,
#   ('fans', 245): False,
#   ('sound', 245): False,
#   ('worse', 245): False,
#   ('piece', 244): False,
#   ('involving', 244): False,
#   ('de', 244): False,
#   ('appears', 243): False,
#   ('planet', 243): False,
#   ('paul', 243): False,
#   ('involved', 243): False,
#   ('mean', 242): False,
#   ('none', 242): False,
#   ('taking', 242): False,
#   ('hours', 242): False,
#   ('laugh', 242): False,
#   ('police', 241): False,
#   ('sets', 241): False,
#   ('attention', 241): False,
#   ('co', 241): False,
#   ('hell', 240): False,
#   ('eventually', 240): False,
#   ('single', 239): False,
#   ('fall', 239): False,
#   ('falls', 239): False,
#   ('material', 239): False,
#   ('emotional', 239): False,
#   ('power', 238): False,
#   ('late', 238): False,
#   ('lack', 237): False,
#   ('dr', 237): False,
#   ('van', 237): False,
#   ('result', 237): False,
#   ('elements', 236): False,
#   ('experience', 236): False,
#   ('meet', 236): False,
#   ('smith', 236): False,
#   ('science', 235): False,
#   ('bring', 235): False,
#   ('wild', 235): False,
#   ('living', 234): False,
#   ('theater', 234): False,
#   ('interest', 232): False,
#   ('leads', 231): False,
#   ('word', 231): False,
#   ('feature', 230): False,
#   ('battle', 230): False,
#   ('alone', 230): False,
#   ('girls', 229): False,
#   ('obviously', 228): False,
#   ('george', 228): False,
#   ('within', 227): False,
#   ('usually', 227): False,
#   ('enjoy', 227): False,
#   ('guess', 226): False,
#   ('among', 226): False,
#   ('taken', 225): False,
#   ('feeling', 225): False,
#   ('laughs', 225): False,
#   ('aliens', 225): False,
#   ('talk', 224): False,
#   ('chance', 223): False,
#   ('talent', 223): False,
#   ('3', 222): False,
#   ('middle', 222): False,
#   ('number', 222): False,
#   ('easy', 222): False,
#   ('happen', 221): False,
#   ('across', 221): False,
#   ('needs', 221): False,
#   ('attempts', 221): False,
#   ('television', 220): False,
#   ('chris', 220): False,
#   ('deal', 219): False,
#   ('poor', 219): False,
#   ('form', 219): False,
#   ('girlfriend', 218): False,
#   ('viewer', 218): False,
#   ('release', 218): False,
#   ('killed', 218): False,
#   ('forced', 218): False,
#   ('whether', 217): False,
#   ('wonderful', 217): False,
#   ('feels', 216): False,
#   ('oh', 216): False,
#   ('tale', 216): False,
#   ('serious', 216): False,
#   ('leave', 216): False,
#   ('expect', 216): False,
#   ('except', 216): False,
#   ('light', 216): False,
#   ('success', 216): False,
#   ('features', 216): False,
#   ('premise', 216): False,
#   ('happy', 215): False,
#   ('words', 215): False,
#   ('important', 215): False,
#   ('meets', 215): False,
#   ('history', 215): False,
#   ('ryan', 215): False,
#   ('giving', 214): False,
#   ('crew', 214): False,
#   ('type', 214): False,
#   ('call', 214): False,
#   ('turned', 214): False,
#   ('released', 214): False,
#   ('parents', 214): False,
#   ('art', 214): False,
#   ('impressive', 214): False,
#   ('mission', 213): False,
#   ('working', 213): False,
#   ('seemed', 212): False,
#   ('score', 212): False,
#   ('told', 212): False,
#   ('america', 212): False,
#   ('recent', 211): False,
#   ('robin', 211): False,
#   ('basically', 211): False,
#   ('entertainment', 211): False,
#   ('surprise', 210): False,
#   ('apparently', 209): False,
#   ('easily', 209): False,
#   ('cool', 208): False,
#   ('stuff', 208): False,
#   ('cop', 208): False,
#   ('change', 208): False,
#   ('williams', 208): False,
#   ('crime', 208): False,
#   ('office', 208): False,
#   ('parts', 207): False,
#   ('somehow', 207): False,
#   ('sequel', 207): False,
#   ('william', 206): False,
#   ('cut', 206): False,
#   ('die', 205): False,
#   ('jones', 204): False,
#   ('credits', 203): False,
#   ('batman', 203): False,
#   ('suspense', 202): False,
#   ('brings', 202): False,
#   ('reality', 202): False,
#   ('events', 201): False,
#   ('local', 201): False,
#   ('talking', 200): False,
#   ('difficult', 200): False,
#   ('using', 200): False,
#   ('went', 200): False,
#   ('writing', 200): False,
#   ('remember', 200): False,
#   ('near', 200): False,
#   ('straight', 200): False,
#   ('hilarious', 200): False,
#   ('ago', 199): False,
#   ('certain', 199): False,
#   ('ben', 199): False,
#   ('red', 198): False,
#   ('kid', 198): False,
#   ('slow', 198): False,
#   ('blood', 198): False,
#   ('mystery', 198): False,
#   ('complete', 197): False,
#   ('popular', 197): False,
#   ('effective', 197): False,
#   ('fast', 197): False,
#   ('flick', 196): False,
#   ('due', 196): False,
#   ('runs', 196): False,
#   ('gone', 195): False,
#   ('return', 195): False,
#   ('presence', 195): False,
#   ('quality', 195): False,
#   ('dramatic', 194): False,
#   ('filmmakers', 194): False,
#   ('age', 194): False,
#   ('brothers', 194): False,
#   ('business', 193): False,
#   ('general', 193): False,
#   ('rock', 192): False,
#   ('sexual', 192): False,
#   ('present', 192): False,
#   ('surprisingly', 191): False,
#   ('anyway', 191): False,
#   ('uses', 191): False,
#   ('4', 190): False,
#   ('personal', 190): False,
#   ('figure', 190): False,
#   ('smart', 190): False,
#   ('ways', 189): False,
#   ('decides', 189): False,
#   ('annoying', 189): False,
#   ('begin', 189): False,
#   ('somewhat', 188): False,
#   ('shots', 188): False,
#   ('rich', 188): False,
#   ('minute', 187): False,
#   ('law', 187): False,
#   ('previous', 186): False,
#   ('jim', 186): False,
#   ('successful', 186): False,
#   ('harry', 186): False,
#   ('water', 186): False,
#   ('similar', 186): False,
#   ('absolutely', 186): False,
#   ('motion', 186): False,
#   ('former', 186): False,
#   ('strange', 185): False,
#   ('came', 185): False,
#   ('follow', 185): False,
#   ('read', 185): False,
#   ('project', 185): False,
#   ('million', 185): False,
#   ('secret', 184): False,
#   ('starring', 184): False,
#   ('clear', 184): False,
#   ('familiar', 184): False,
#   ('eye', 184): False,
#   ('romance', 184): False,
#   ('intelligent', 184): False,
#   ('third', 184): False,
#   ('excellent', 184): False,
#   ('amazing', 184): False,
#   ('party', 183): False,
#   ('budget', 183): False,
#   ('actress', 183): False,
#   ('prison', 183): False,
#   ('latest', 183): False,
#   ('means', 183): False,
#   ('company', 183): False,
#   ('towards', 182): False,
#   ('predictable', 182): False,
#   ('powerful', 182): False,
#   ('bob', 182): False,
#   ('beyond', 181): False,
#   ('visual', 181): False,
#   ('leaves', 181): False,
#   ('r', 180): False,
#   ('nature', 180): False,
#   ('following', 180): False,
#   ('villain', 180): False,
#   ('leaving', 180): False,
#   ('wars', 180): False,
#   ('animated', 179): False,
#   ('low', 179): False,
#   ('b', 179): False,
#   ('bill', 179): False,
#   ('sam', 179): False,
#   ('filled', 179): False,
#   ('questions', 178): False,
#   ('cinema', 178): False,
#   ('message', 178): False,
#   ('box', 178): False,
#   ('moving', 178): False,
#   ('country', 178): False,
#   ('usual', 177): False,
#   ('martin', 177): False,
#   ('definitely', 177): False,
#   ('add', 177): False,
#   ('large', 177): False,
#   ('clever', 177): False,
#   ('create', 177): False,
#   ('felt', 176): False,
#   ('stories', 176): False,
#   ('brilliant', 176): False,
#   ('ones', 176): False,
#   ('giant', 176): False,
#   ('situation', 176): False,
#   ('murphy', 176): False,
#   ('break', 175): False,
#   ('opens', 175): False,
#   ('scary', 175): False,
#   ('doubt', 175): False,
#   ('drug', 175): False,
#   ('bunch', 174): False,
#   ('thinking', 174): False,
#   ('solid', 174): False,
#   ('effect', 173): False,
#   ('learn', 172): False,
#   ('move', 172): False,
#   ('force', 171): False,
#   ('potential', 171): False,
#   ('seriously', 171): False,
#   ('follows', 170): False,
#   ('huge', 170): False,
#   ('saying', 170): False,
#   ('class', 169): False,
#   ('plan', 169): False,
#   ('agent', 168): False,
#   ('created', 167): False,
#   ('unlike', 167): False,
#   ('pay', 166): False,
#   ('non', 166): False,
#   ('married', 166): False,
#   ('mark', 166): False,
#   ('sweet', 166): False,
#   ('perfectly', 166): False,
#   ('ex', 165): False,
#   ('realize', 165): False,
#   ('audiences', 165): False,
#   ('took', 164): False,
#   ('decent', 164): False,
#   ('likely', 164): False,
#   ('dream', 164): False,
#   ('view', 164): False,
#   ('scott', 164): False,
#   ('subject', 164): False,
#   ('understand', 164): False,
#   ('happened', 164): False,
#   ('enjoyable', 164): False,
#   ('studio', 163): False,
#   ('immediately', 163): False,
#   ('open', 163): False,
#   ('e', 163): False,
#   ('points', 163): False,
#   ('heard', 163): False,
#   ('viewers', 163): False,
#   ('cameron', 163): False,
#   ('truman', 163): False,
#   ('bruce', 162): False,
#   ('frank', 162): False,
#   ('private', 161): False,
#   ('stay', 161): False,
#   ('fails', 161): False,
#   ('impossible', 161): False,
#   ('cold', 161): False,
#   ('richard', 161): False,
#   ('overall', 160): False,
#   ('merely', 160): False,
#   ('exciting', 160): False,
#   ('mess', 159): False,
#   ('chase', 159): False,
#   ('escape', 159): False,
#   ('free', 159): False,
#   ('ten', 159): False,
#   ('neither', 159): False,
#   ('wanted', 159): False,
#   ('gun', 159): False,
#   ('appear', 159): False,
#   ('carter', 159): False,
#   ('ultimately', 158): False,
#   ('fan', 158): False,
#   ('inside', 157): False,
#   ('favorite', 157): False,
#   ('modern', 157): False,
#   ('l', 157): False,
#   ('wedding', 157): False,
#   ('stone', 157): False,
#   ('trek', 157): False,
#   ('brought', 157): False,
#   ('trouble', 157): False,
#   ('otherwise', 156): False,
#   ('tim', 156): False,
#   ('5', 156): False,
#   ('allen', 156): False,
#   ('bond', 155): False,
#   ('society', 155): False,
#   ('liked', 155): False,
#   ('dumb', 155): False,
#   ('musical', 154): False,
#   ('stand', 154): False,
#   ('political', 154): False,
#   ('various', 154): False,
#   ('talented', 154): False,
#   ('particular', 154): False,
#   ('west', 154): False,
#   ('state', 153): False,
#   ('keeps', 153): False,
#   ('english', 152): False,
#   ('silly', 152): False,
#   ('u', 152): False,
#   ('situations', 152): False,
#   ('park', 152): False,
#   ('teen', 151): False,
#   ('rating', 151): False,
#   ('slightly', 151): False,
#   ('steve', 151): False,
#   ('truth', 151): False,
#   ('air', 151): False,
#   ('element', 150): False,
#   ('joke', 150): False,
#   ('spend', 150): False,
#   ('key', 150): False,
#   ('biggest', 149): False,
#   ('members', 149): False,
#   ('effort', 149): False,
#   ('government', 149): False,
#   ('focus', 149): False,
#   ('today', 149): False,
#   ('eddie', 149): False,
#   ('soundtrack', 148): False,
#   ('hands', 148): False,
#   ('earlier', 148): False,
#   ('chan', 148): False,
#   ('purpose', 148): False,
#   ('showing', 147): False,
#   ('memorable', 147): False,
#   ('six', 147): False,
#   ('max', 147): False,
#   ('offers', 147): False,
#   ('rated', 146): False,
#   ('mars', 146): False,
#   ('heavy', 146): False,
#   ('totally', 146): False,
#   ('control', 145): False,
#   ('credit', 145): False,
#   ('fi', 145): False,
#   ('woody', 145): False,
#   ('ideas', 144): False,
#   ('sci', 144): False,
#   ('wait', 144): False,
#   ('sit', 144): False,
#   ('female', 143): False,
#   ('ask', 143): False,
#   ('waste', 143): False,
#   ('terrible', 143): False,
#   ('depth', 143): False,
#   ('simon', 143): False,
#   ('aspect', 143): False,
#   ('list', 143): False,
#   ('mary', 143): False,
#   ('sister', 143): False,
#   ('animation', 142): False,
#   ('entirely', 142): False,
#   ('fear', 142): False,
#   ('steven', 142): False,
#   ('moves', 142): False,
#   ('actual', 142): False,
#   ('army', 142): False,
#   ('british', 142): False,
#   ('constantly', 142): False,
#   ('fire', 142): False,
#   ('convincing', 141): False,
#   ('setting', 141): False,
#   ('gave', 141): False,
#   ('tension', 141): False,
#   ('street', 140): False,
#   ('8', 140): False,
#   ('brief', 140): False,
#   ('ridiculous', 140): False,
#   ('cinematography', 140): False,
#   ('typical', 140): False,
#   ('nick', 140): False,
#   ('screenwriter', 140): False,
#   ('ability', 140): False,
#   ('spent', 140): False,
#   ('quick', 139): False,
#   ('violent', 139): False,
#   ('atmosphere', 139): False,
#   ('subtle', 139): False,
#   ('expected', 138): False,
#   ('fairly', 138): False,
#   ('seven', 138): False,
#   ('disaster', 138): False,
#   ('killing', 138): False,
#   ('tone', 138): False,
#   ('master', 138): False,
#   ('highly', 137): False,
#   ('lots', 137): False,
#   ('thinks', 137): False,
#   ('song', 137): False,
#   ('cheap', 137): False,
#   ('suddenly', 137): False,
#   ('background', 137): False,
#   ('club', 137): False,
#   ('willis', 137): False,
#   ('whatever', 136): False,
#   ('sees', 136): False,
#   ('complex', 136): False,
#   ('greatest', 136): False,
#   ('impact', 136): False,
#   ('ii', 136): False,
#   ('beauty', 135): False,
#   ('front', 135): False,
#   ('humans', 135): False,
#   ('indeed', 135): False,
#   ('flat', 135): False,
#   ('grace', 135): False,
#   ('wrote', 135): False,
#   ('amusing', 135): False,
#   ('titanic', 135): False,
#   ('mike', 135): False,
#   ('cute', 134): False,
#   ('dull', 134): False,
#   ('minor', 134): False,
#   ('recently', 134): False,
#   ('hate', 134): False,
#   ('outside', 134): False,
#   ('plenty', 134): False,
#   ('wish', 134): False,
#   ('godzilla', 134): False,
#   ('college', 134): False,
#   ('sounds', 133): False,
#   ('telling', 133): False,
#   ('sight', 133): False,
#   ('double', 133): False,
#   ('cinematic', 133): False,
#   ('queen', 133): False,
#   ('hold', 133): False,
#   ('meanwhile', 133): False,
#   ('awful', 132): False,
#   ('clearly', 132): False,
#   ('theme', 132): False,
#   ('hear', 132): False,
#   ('x', 132): False,
#   ('amount', 132): False,
#   ('baby', 132): False,
#   ('approach', 132): False,
#   ('dreams', 131): False,
#   ('shown', 131): False,
#   ('island', 131): False,
#   ('reasons', 131): False,
#   ('charm', 131): False,
#   ('miss', 131): False,
#   ('longer', 131): False,
#   ('common', 130): False,
#   ('sean', 130): False,
#   ('carry', 130): False,
#   ('believable', 130): False,
#   ('realistic', 130): False,
#   ('chemistry', 130): False,
#   ('possibly', 129): False,
#   ('casting', 129): False,
#   ('somewhere', 128): False,
#   ('carrey', 128): False,
#   ('french', 128): False,
#   ('trailer', 128): False,
#   ('tough', 128): False,
#   ('produced', 128): False,
#   ('imagine', 128): False,
#   ('choice', 128): False,
#   ('ride', 128): False,
#   ('hot', 127): False,
#   ('race', 127): False,
#   ('road', 127): False,
#   ('leader', 127): False,
#   ('thin', 127): False,
#   ('jerry', 127): False,
#   ('slowly', 127): False,
#   ('delivers', 127): False,
#   ('detective', 127): False,
#   ('brown', 127): False,
#   ('jackson', 127): False,
#   ('member', 126): False,
#   ('provide', 126): False,
#   ('president', 126): False,
#   ('puts', 126): False,
#   ('asks', 126): False,
#   ('critics', 126): False,
#   ('appearance', 126): False,
#   ('famous', 126): False,
#   ('okay', 125): False,
#   ('intelligence', 125): False,
#   ('energy', 125): False,
#   ('sent', 125): False,
#   ('spielberg', 125): False,
#   ('development', 125): False,
#   ('etc', 125): False,
#   ('language', 125): False,
#   ('blue', 125): False,
#   ('proves', 125): False,
#   ('vampire', 125): False,
#   ('seemingly', 124): False,
#   ('basic', 124): False,
#   ('caught', 124): False,
#   ('decide', 124): False,
#   ...},
#  'neg')
